# %% [markdown]
# # Data cleaning

# %% [markdown]
# # Preprocessing

# %%
import pandas as pd

# %%
df = pd.read_excel("../data/raw/datos-sismicos.xlsx")

# %% [markdown]
# ## Correcting the type of values

# %%
for i in df.columns:
    print("- ", i, ": ", df[i].dtype)
# Out:
# -  fecha UTC :  str
# -  hora UTC :  str
# -  latitud (º) :  float64
# -  longitud (º) :  float64
# -  profundidad (km) :  int64
# -  magnitud (M) :  float64

# %%
# "fecha UTC" should be date type, and "hora UTC" should be hour

fecha = df["fecha UTC"].str.strip()

hora = df["hora UTC"].str.strip().str.split(".", n=1).str[0]

df["fecha"] = pd.to_datetime(
                    fecha + " " + hora,
                    format= "%Y-%m-%d %H:%M:%S",
                    utc= True
)

# %%
df["fecha"]
# Out:
# 0       1960-01-13 15:40:34+00:00
# 1       1960-01-15 09:30:24+00:00
# 2       1960-01-17 02:57:58+00:00
# 3       1960-01-23 03:37:32+00:00
# 4       1960-01-30 05:07:24+00:00
#                    ...
# 25117   2026-02-05 05:30:03+00:00
# 25118   2026-02-05 11:07:38+00:00
# 25119   2026-02-05 18:20:45+00:00
# 25120   2026-02-05 20:56:34+00:00
# 25121   2026-02-05 21:32:23+00:00
# Name: fecha, Length: 25122, dtype: datetime64[us, UTC]

# %%
df = df[["fecha", "latitud (º)", "longitud (º)", "profundidad (km)", "magnitud (M)"]]

# %% [markdown]
# ## Adjusting the column names

# %%
df = df.rename(columns={
        'fecha': 'date', 
        'latitud (º)':'latitude',
        'longitud (º)': 'longitude',
        'profundidad (km)': 'depth',
        'magnitud (M)': 'magnitude'
        }
    )

# %% [markdown]
# ## Turning the hour to Peruvian Timezone

# %%
df["date"] = df["date"].dt.tz_convert("America/Lima")

# %% [markdown]
# ## First Export

# %%
df.to_csv("../data/processed/earthquake_clean.csv", index=False)

# %% [markdown]
# # Final Processing for Analysis

# %%
df = pd.read_csv("../data/processed/earthquake_clean.csv")

df["date"] = pd.to_datetime(df["date"], utc=True)

# %% [markdown]
# ## Date separation

# %%
df["year"] = df["date"].dt.year
df["month"] = df["date"].dt.month
df["day"] = df["date"].dt.day
df["hour"] = df["date"].dt.hour

# %% [markdown]
# ## Location

# %%
import geopandas as gpd

deps = gpd.read_file("../data/raw/DEPARTAMENTOS")

# %%
deps.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
deps.columns
# Out:
# Index(['OBJECTID', 'CODDEP', 'DEPARTAMEN', 'CAPITAL', 'FUENTE', 'geometry'], dtype='str')

# %%
gdf = gpd.GeoDataFrame(
    df,
    geometry = gpd.points_from_xy(df["longitude"], df["latitude"]),
    crs="EPSG:4326"
)

# %%
deps = deps.to_crs(gdf.crs)

# %%
gdf = gpd.sjoin(gdf, deps, how="left", predicate="intersects")

# %%
gdf.columns
# Out:
# Index(['Unnamed: 0', 'date', 'latitude', 'longitude', 'depth', 'magnitude',
#        'year', 'month', 'day', 'hour', 'geometry', 'index_right', 'OBJECTID',
#        'CODDEP', 'DEPARTAMEN', 'CAPITAL', 'FUENTE'],
#       dtype='str')

# %%
gdf
# Out:
#        Unnamed: 0                      date  latitude  longitude  depth  \
# 0               0 1960-01-13 15:40:34+00:00   -16.145    -72.144     60
# 1               1 1960-01-15 09:30:24+00:00   -15.000    -75.000     70
# 2               2 1960-01-17 02:57:58+00:00   -14.500    -74.500    150
# 3               3 1960-01-23 03:37:32+00:00   -12.500    -68.500    300
# 4               4 1960-01-30 05:07:24+00:00    -5.500    -77.500    100
# ...           ...                       ...       ...        ...    ...
# 25117       25117 2026-02-05 05:30:03+00:00   -13.670    -76.110     51
# 25118       25118 2026-02-05 11:07:38+00:00   -11.190    -74.660    130
# 25119       25119 2026-02-05 18:20:45+00:00   -10.730    -73.900    117
# 25120       25120 2026-02-05 20:56:34+00:00   -15.200    -74.060    106
# 25121       25121 2026-02-05 21:32:23+00:00    -5.620    -80.300     47
#
#        magnitude  year  month  day  hour                 geometry  \
# 0            7.5  1960      1   13    15  POINT (-72.144 -16.145)
# 1            7.0  1960      1   15     9          POINT (-75 -15)
# 2            6.4  1960      1   17     2      POINT (-74.5 -14.5)
# 3            5.8  1960      1   23     3      POINT (-68.5 -12.5)
# 4            5.7  1960      1   30     5       POINT (-77.5 -5.5)
# ...          ...   ...    ...  ...   ...                      ...
# 25117        3.8  2026      2    5     5    POINT (-76.11 -13.67)
# 25118        4.0  2026      2    5    11    POINT (-74.66 -11.19)
# 25119        4.0  2026      2    5    18     POINT (-73.9 -10.73)
# 25120        4.0  2026      2    5    20     POINT (-74.06 -15.2)
# 25121        3.8  2026      2    5    21      POINT (-80.3 -5.62)
#
#        index_right  OBJECTID CODDEP DEPARTAMEN   CAPITAL FUENTE
# 0              3.0       4.0     04   AREQUIPA  AREQUIPA   INEI
# 1             10.0      11.0     11        ICA       ICA   INEI
# 2              4.0       5.0     05   AYACUCHO  AYACUCHO   INEI
# 3              NaN       NaN    NaN        NaN       NaN    NaN
# 4             15.0      16.0     16     LORETO   IQUITOS   INEI
# ...            ...       ...    ...        ...       ...    ...
# 25117         10.0      11.0     11        ICA       ICA   INEI
# 25118         11.0      12.0     12      JUNIN  HUANCAYO   INEI
# 25119         24.0      25.0     25    UCAYALI  PUCALLPA   INEI
# 25120          4.0       5.0     05   AYACUCHO  AYACUCHO   INEI
# 25121         19.0      20.0     20      PIURA     PIURA   INEI
#
# [25122 rows x 17 columns]

# %%
df["department"] = gdf["DEPARTAMEN"]

# %%
df = df[["depth", "magnitude", "year", "month", "day", "hour", "department"]]

# %%
# Eliminating the NaN values because they are outside the Peru limits

df = df.dropna(subset=["department"])

# %%
df
# Out:
#        depth  magnitude  year  month  day  hour department
# 0         60        7.5  1960      1   13    15   AREQUIPA
# 1         70        7.0  1960      1   15     9        ICA
# 2        150        6.4  1960      1   17     2   AYACUCHO
# 4        100        5.7  1960      1   30     5     LORETO
# 5        136        5.3  1960      2    8    19    UCAYALI
# ...      ...        ...   ...    ...  ...   ...        ...
# 25117     51        3.8  2026      2    5     5        ICA
# 25118    130        4.0  2026      2    5    11      JUNIN
# 25119    117        4.0  2026      2    5    18    UCAYALI
# 25120    106        4.0  2026      2    5    20   AYACUCHO
# 25121     47        3.8  2026      2    5    21      PIURA
#
# [14723 rows x 7 columns]

# %%
df.to_csv("../data/processed/earthquake_analysis_ready.csv", index=False)
