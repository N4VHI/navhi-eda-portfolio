# %% [markdown]
# # Data understanding

# %%
import pandas as pd

# %%
df = pd.read_excel("../data/raw/datos-sismicos.xlsx")

# %%
df.head()
# Out:
#     fecha UTC     hora UTC  latitud (º)  longitud (º)  profundidad (km)  \
# 0  1960-01-13  15:40:34.00      -16.145       -72.144                60
# 1  1960-01-15  09:30:24.00      -15.000       -75.000                70
# 2  1960-01-17  02:57:58.00      -14.500       -74.500               150
# 3  1960-01-23  03:37:32.00      -12.500       -68.500               300
# 4  1960-01-30  05:07:24.00       -5.500       -77.500               100
#
#    magnitud (M)
# 0           7.5
# 1           7.0
# 2           6.4
# 3           5.8
# 4           5.7

# %%
df.count()
# Out:
# fecha UTC           25122
# hora UTC            25122
# latitud (º)         25122
# longitud (º)        25122
# profundidad (km)    25122
# magnitud (M)        25122
# dtype: int64

# %%
df.columns
# Out:
# Index(['fecha UTC', 'hora UTC', 'latitud (º)', 'longitud (º)',
#        'profundidad (km)', 'magnitud (M)'],
#       dtype='str')

# %%
for i in df.columns:
    print("- ", i, ": ", df[i].dtype)
# Out:
# -  fecha UTC :  str
# -  hora UTC :  str
# -  latitud (º) :  float64
# -  longitud (º) :  float64
# -  profundidad (km) :  int64
# -  magnitud (M) :  float64
